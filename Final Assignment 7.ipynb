# %%
#Tamoghna Pattanayak,1811168

#Question 1(a)

# %%
import math
from Mylibrary import *

# dy / dx =(x + y + xy) 
def func( x, y ): 
    return ((y * math.log(y))/x)





file = open("Q1a_p02.dat", "w+")
 
x0 = 2
y = 2.71828
h = 0.02
  
# Value of x at which we need approximation 
x = 30
  
euler(x0, y, h,func, x,file) 

file = open("Q1a_p02.dat", "r")
print("--------------------------------")
print("For h=0.02")
print("{:<15.6}{:<15.10}".format("x", "y"))
#print("--------------------------------")
print(file.read())





file1 = open("Q1a_p05.dat", "w+")
 
x0 = 2
y = 2.71828
h = 0.05
  
# Value of x at which we need approximation 
x = 30
  
euler(x0, y, h,func, x,file1) 

file1 = open("Q1a_p05.dat", "r")
print("--------------------------------")
print("For h=0.05")
print("{:<15.6}{:<15.10}".format("x", "y"))
#print("--------------------------------")
print(file1.read())







file2 = open("Q1a_p5.dat", "w+")
 
x0 = 2
y = 2.71828
h = 0.5
  
# Value of x at which we need approximation 
x = 30
  
euler(x0, y, h,func, x,file2) 

file2 = open("Q1a_p5.dat", "r")
print("--------------------------------")
print("For h=0.5")
print("{:<15.6}{:<15.10}".format("x", "y"))
#print("--------------------------------")
print(file2.read())





file3 = open("Q1a_p2.dat", "w+")
 
x0 = 2
y = 2.71828
h = 0.2
  
# Value of x at which we need approximation 
x = 30
  
euler(x0, y, h,func, x,file3) 

file3 = open("Q1a_p2.dat", "r")
print("--------------------------------")
print("For h=0.2")
print("{:<15.6}{:<15.10}".format("x", "y"))
#print("--------------------------------")
print(file3.read())
# Out:
# --------------------------------
# For h=0.02
# x              y
# 2              2.71828
# 2.02           2.745462782
# 2.04           2.772916041
# 2.06           2.800642469
# 2.08           2.828644784
# 2.1            2.85692573
# 2.12           2.885488079
# 2.14           2.914334632
# 2.16           2.943468215
# 2.18           2.972891683
# 2.2            3.002607921
# 2.22           3.032619839
# 2.24           3.062930379
# 2.26           3.093542512
# 2.28           3.124459235
# 2.3            3.155683579
# 2.32           3.187218604
# 2.34           3.219067397
# 2.36           3.251233081
# 2.38           3.283718805
# 2.4            3.316527752
# 2.42           3.349663136
# 2.44           3.383128202
# 2.46           3.416926229
# 2.48           3.451060527
# 2.5            3.485534439
# 2.52           3.520351342
# 2.54           3.555514645
# 2.56           3.591027793
# 2.58           3.626894261
# 2.6            3.663117564
# 2.62           3.699701249
# ...

# %%
#Question 1(b)

# %%
import math
from Mylibrary import *

# dy / dx =(x + y + xy) 
def func( x, y ): 
    return (6 - (2*y)/x)





file = open("Q1b_p02.dat", "w+")
 
x0 = 3
y = 1
h = 0.02
  
# Value of x at which we need approximation 
x = 30
  
euler(x0, y, h,func, x,file) 

file = open("Q1b_p02.dat", "r")
print("--------------------------------")
print("For h=0.02")
print("{:<15.6}{:<15.10}".format("x", "y"))
#print("--------------------------------")
print(file.read())





file1 = open("Q1b_p05.dat", "w+")
 
x0 = 3
y = 1
h = 0.05
  
# Value of x at which we need approximation 
x = 30
  
euler(x0, y, h,func, x,file1) 

file1 = open("Q1b_p05.dat", "r")
print("--------------------------------")
print("For h=0.05")
print("{:<15.6}{:<15.10}".format("x", "y"))
#print("--------------------------------")
print(file1.read())







file2 = open("Q1b_p5.dat", "w+")
 
x0 = 3
y = 1
h = 0.5
  
# Value of x at which we need approximation 
x = 30
  
euler(x0, y, h,func, x,file2) 

file2 = open("Q1b_p5.dat", "r")
print("--------------------------------")
print("For h=0.5")
print("{:<15.6}{:<15.10}".format("x", "y"))
#print("--------------------------------")
print(file2.read())





file3 = open("Q1b_p2.dat", "w+")
 
x0 = 3
y = 1
h = 0.2
  
# Value of x at which we need approximation 
x = 30
  
euler(x0, y, h,func, x,file3) 

file3 = open("Q1b_p2.dat", "r")
print("--------------------------------")
print("For h=0.2")
print("{:<15.6}{:<15.10}".format("x", "y"))
#print("--------------------------------")
print(file3.read())
# Out:
# --------------------------------
# For h=0.02
# x              y
# 3              1
# 3.02           1.106666667
# 3.04           1.21200883
# 3.06           1.316061345
# 3.08           1.418857929
# 3.1            1.520431203
# 3.12           1.620812736
# 3.14           1.720033085
# 3.16           1.818121836
# 3.18           1.915107635
# 3.2            2.011018231
# 3.22           2.105880503
# 3.24           2.199720497
# 3.26           2.292563454
# 3.28           2.384433841
# 3.3            2.475355379
# 3.32           2.565351072
# 3.34           2.654443227
# 3.36           2.742653488
# 3.38           2.830002851
# 3.4            2.916511693
# 3.42           3.002199791
# 3.44           3.087086343
# 3.46           3.17118999
# 3.48           3.254528835
# 3.5            3.337120457
# 3.52           3.418981938
# 3.54           3.50012987
# 3.56           3.58058038
# 3.58           3.66034914
# 3.6            3.739451384
# 3.62           3.817901924
# ...

# %%
#Question 2

# %%
import math
from Mylibrary import *


def func2( x, y,z): 
    return (1-x-z)


def func1(x,y,z):
    return z








file = open("Q2_p02.dat", "w+")

x0 = 0
y0 = 2
z0 = 1
# Value of x at which we need approximation
x = 15

h = 0.02

rk4(x0, y0, z0, h,func1, func2, x,file)

file = open("Q2_p02.dat", "r")
print("--------------------------------")
print("for h 0.02")
print("{:<15.6}{:<15.10}".format("x", "y"))
print("--------------------------------")
print(file.read())








file1 = open("Q2_p2.dat", "w+")

x0 = 0
y0 = 2
z0 = 1
# Value of x at which we need approximation
x = 15

h = 0.2

rk4(x0, y0, z0, h,func1, func2, x,file1)

file1 = open("Q2_p2.dat", "r")
print("--------------------------------")
print("for h 0.2")
print("{:<15.6}{:<15.10}".format("x", "y"))
print("--------------------------------")
print(file1.read())







file2 = open("Q2_p05.dat", "w+")

x0 = 0
y0 = 2
z0 = 1
# Value of x at which we need approximation
x = 15

h = 0.05

rk4(x0, y0, z0, h,func1, func2, x,file2)

file2 = open("Q2_p05.dat", "r")
print("--------------------------------")
print("for h 0.05")
print("{:<15.6}{:<15.10}".format("x", "y"))
print("--------------------------------")
print(file2.read())







file3 = open("Q2_p5.dat", "w+")

x0 = 0
y0 = 2
z0 = 1
# Value of x at which we need approximation
x = 15

h = 0.5

rk4(x0, y0, z0, h,func1, func2, x,file3)

file3 = open("Q2_p5.dat", "r")
print("--------------------------------")
print("for h 0.5")
print("{:<15.6}{:<15.10}".format("x", "y"))
print("--------------------------------")
print(file3.read())
# Out:
# --------------------------------
# for h 0.02
# x              y
# --------------------------------
# 0              2
# 0.02           2.019998673
# 0.04           2.039989439
# 0.06           2.059964534
# 0.08           2.079916346
# 0.1            2.099837418
# 0.12           2.119720437
# 0.14           2.139558236
# 0.16           2.159343789
# 0.18           2.179070212
# 0.2            2.198730753
# 0.22           2.218318798
# 0.24           2.237827861
# 0.26           2.257251586
# 0.28           2.276583742
# 0.3            2.295818221
# 0.32           2.314949037
# 0.34           2.333970323
# 0.36           2.352876326
# 0.38           2.37166141
# 0.4            2.390320046
# 0.42           2.40884682
# 0.44           2.427236421
# 0.46           2.445483646
# 0.48           2.463583392
# 0.5            2.48153066
# 0.52           2.499320548
# 0.54           2.516948253
# 0.56           2.534409064
# 0.58           2.551698367
# 0.6            2.568811637
# ...

# %%
#Question 3

# %%
import math
from Mylibrary import *



file1 = open("Q3h_p01.dat", "w+")
file2 = open("Q3l_p01.dat", "w+")

def func2(x, y, z):
    return (z+1)

def func1(x, y, z):
    return (z)

x0 = 0
y0 = 1
zh0 = 2
zl0 = 0

xn = 1
yn = 2 * (2.71828 - 1)
h = 0.05

shoting_method(x0, y0, zh0, zl0, xn, yn, h, func1, func2, file1, file2)
# Out:
# For boundary condition, Yn =  3.43656
# After Langarangian interpolation, The value of Z = 0.9999980298267261
# And for Z = 0.9999980298267261 , The calculated value of Yn = 3.43656
